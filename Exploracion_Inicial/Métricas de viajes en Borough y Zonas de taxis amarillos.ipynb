# %% [markdown]
# ## Métricas de viajes en Borough y Zonas
# #### Utilizando el dataset: ‘yellow_tripdata_2023-09.parquet’
# Heidi 7/12/23
# Siguiendo la sugerencia del repo NYC Taxis CO2” se validan las Ideas de análisis e implementación
# * Viajes inter e intra boroughs
# * Borough con mayor/menor cantidad de viajes
# * Viajes entre distintas Zonas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# Abir dataset de taxis de NYC

# %%
# Especifica la ruta del archivo Parquet
ruta_archivo_parquet = 'Datasets\yellow_tripdata_2023-09.parquet' 

# Lee el archivo Parquet en un DataFrame de pandas
df_taxi_2023_09 = pd.read_parquet(ruta_archivo_parquet)

# Muestra las primeras filas del DataFrame
df_taxi_2023_09.head(20)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2023-09-01 00:15:37   2023-09-01 00:20:21              1.0
# 1          2  2023-09-01 00:18:40   2023-09-01 00:30:28              2.0
# 2          2  2023-09-01 00:35:01   2023-09-01 00:39:04              1.0
# 3          2  2023-09-01 00:45:45   2023-09-01 00:47:37              1.0
# 4          2  2023-09-01 00:01:23   2023-09-01 00:38:05              1.0
# 5          2  2023-09-01 00:05:20   2023-09-01 00:46:57              3.0
# 6          1  2023-09-01 00:51:50   2023-09-01 01:10:21              0.0
# 7          1  2023-09-01 00:01:04   2023-09-01 00:18:36              1.0
# 8          2  2023-09-01 00:37:44   2023-09-01 00:52:24              2.0
# 9          2  2023-09-01 00:02:13   2023-09-01 00:07:12              1.0
# 10         2  2023-09-01 00:30:18   2023-09-01 00:58:36              1.0
# 11         2  2023-09-01 00:08:32   2023-09-01 00:15:58              2.0
# 12         2  2023-09-01 00:03:56   2023-09-01 00:23:09              1.0
# 13         2  2023-09-01 00:40:28   2023-09-01 00:53:42              1.0
# 14         2  2023-09-01 00:57:50   2023-09-01 01:02:37              2.0
# 15         1  2023-09-01 00:04:28   2023-09-01 00:49:20              1.0
# 16         1  2023-09-01 00:06:32   2023-09-01 00:06:41              1.0
# 17         1  2023-09-01 00:18:53   2023-09-01 00:19:08              1.0
# 18         1  2023-09-01 00:31:22   2023-09-01 00:47:53              2.0
# 19         2  2023-09-01 00:04:45   2023-09-01 00:19:27              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.80         1.0                  N           163           230
# 1            2.34         1.0                  N           236           233
# 2            1.62         1.0                  N           162           236
# 3            0.74         1.0                  N           141           229
# 4            9.85         1.0                  N           138           230
# 5           12.83         1.0                  N            93            75
# 6           10.90         1.0                  N            93           255
# 7            3.90         1.0                  N           140             7
# 8            2.70         1.0                  N            45           164
# 9            1.02         1.0                  N           238           236
# 10          16.66         2.0                  N           132           140
# 11           1.37         1.0                  N           138           138
# 12           8.17         1.0                  N           138           170
# 13           2.31         1.0                  N           230           140
# 14           0.95         1.0                  N           234           186
# 15          12.20         1.0                  N            74           189
# 16           0.00         1.0                  Y           161           161
# 17           0.00         1.0                  N           163           161
# 18           2.40         1.0                  N            43            90
# 19           3.28         1.0                  N           142            42
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              2          6.5    3.5      0.5        0.00          0.00
# 1              1         14.2    1.0      0.5        2.00          0.00
# 2              1          8.6    1.0      0.5        2.00          0.00
# 3              1          5.1    1.0      0.5        1.00          0.00
# 4              1         45.0    6.0      0.5       17.02          0.00
# 5              2         55.5    1.0      0.5        0.00          6.94
# 6              1         41.5    1.0      0.5        3.00          0.00
# 7              1         20.5    3.5      0.5        6.35          0.00
# 8              1         16.3    1.0      0.5        4.26          0.00
# 9              1          7.9    1.0      0.5        2.58          0.00
# 10             2         70.0    0.0      0.5        0.00          0.00
# 11             2          9.3    6.0      0.5        0.00          0.00
# 12             1         33.1    6.0      0.5        8.00          6.94
# 13             1         14.9    1.0      0.5        3.98          0.00
# 14             1          7.2    1.0      0.5        2.44          0.00
# 15             1         54.8    3.5      0.5       11.95          0.00
# 16             2          3.0    3.5      0.5        0.00          0.00
# 17             2          3.0    3.5      0.5        0.00          0.00
# 18             1         16.3    3.5      0.5        4.25          0.00
# 19             2         18.4    1.0      0.5        0.00          0.00
#
#     improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                     1.0         11.50                   2.5         0.00
# 1                     1.0         21.20                   2.5         0.00
# 2                     1.0         15.60                   2.5         0.00
# 3                     1.0         11.10                   2.5         0.00
# 4                     1.0         73.77                   2.5         1.75
# 5                     1.0         67.44                   2.5         0.00
# 6                     1.0         47.00                   0.0         0.00
# 7                     1.0         31.85                   2.5         0.00
# 8                     1.0         25.56                   2.5         0.00
# 9                     1.0         15.48                   2.5         0.00
# 10                    1.0         75.75                   2.5         1.75
# 11                    1.0         18.55                   0.0         1.75
# 12                    1.0         59.79                   2.5         1.75
# 13                    1.0         23.88                   2.5         0.00
# 14                    1.0         14.64                   2.5         0.00
# 15                    1.0         71.75                   2.5         0.00
# 16                    1.0          8.00                   2.5         0.00
# 17                    1.0          8.00                   2.5         0.00
# 18                    1.0         25.55                   2.5         0.00
# 19                    1.0         23.40                   2.5         0.00

# %%
df_taxi_2023_09.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846722 entries, 0 to 2846721
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 380.1+ MB

# %% [markdown]
# Selecciono las columnas a utilizar para responder a las metricas

# %%
df_taxi_2023_09_Borough = df_taxi_2023_09[['VendorID',	'tpep_pickup_datetime',	'tpep_dropoff_datetime','PULocationID','DOLocationID']]
df_taxi_2023_09_Borough
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  \
# 0               1  2023-09-01 00:15:37   2023-09-01 00:20:21           163
# 1               2  2023-09-01 00:18:40   2023-09-01 00:30:28           236
# 2               2  2023-09-01 00:35:01   2023-09-01 00:39:04           162
# 3               2  2023-09-01 00:45:45   2023-09-01 00:47:37           141
# 4               2  2023-09-01 00:01:23   2023-09-01 00:38:05           138
# ...           ...                  ...                   ...           ...
# 2846717         2  2023-09-30 23:31:12   2023-09-30 23:48:29           125
# 2846718         1  2023-09-30 23:42:18   2023-09-30 23:47:45           236
# 2846719         1  2023-09-30 23:03:35   2023-09-30 23:14:50           211
# 2846720         2  2023-09-30 23:57:05   2023-10-01 00:17:36           209
# 2846721         1  2023-09-30 23:25:47   2023-09-30 23:55:28            80
#
#          DOLocationID
# 0                 230
# 1                 233
# 2                 236
# 3                 229
# 4                 230
# ...               ...
# 2846717           107
# 2846718            75
# 2846719            90
# 2846720            97
# 2846721           197
#
# [2846722 rows x 5 columns]

# %% [markdown]
# Abro el archivo de zonas y Borough

# %%
df_taxi_zone_lookup = pd.read_csv('Datasets\\taxi+_zone_lookup.csv')
df_taxi_zone_lookup
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %% [markdown]
# Uno el dataset de taxis con el de zonas y borough

# %%
import pandas as pd

# Supongamos que df_taxi_2023_09_Borough y df_taxi_zone_lookup son tus DataFrames originales

# Merging para obtener información de partida
df_merged = pd.merge(df_taxi_2023_09_Borough, df_taxi_zone_lookup, left_on='PULocationID', right_on='LocationID', how='left')
df_merged.rename(columns={'Borough': 'Partida_Borough', 'Zone': 'Partida_Zone'}, inplace=True)
df_merged.drop(columns=['LocationID', 'service_zone'], inplace=True)

# Merging para obtener información de destino
df_merged = pd.merge(df_merged, df_taxi_zone_lookup, left_on='DOLocationID', right_on='LocationID', how='left')
df_merged.rename(columns={'Borough': 'Destino_Borough', 'Zone': 'Destino_Zone'}, inplace=True)
df_merged.drop(columns=['LocationID', 'service_zone'], inplace=True)

# Ahora df_merged tiene las nuevas columnas que necesitas

# %%
df_merged
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  \
# 0               1  2023-09-01 00:15:37   2023-09-01 00:20:21           163
# 1               2  2023-09-01 00:18:40   2023-09-01 00:30:28           236
# 2               2  2023-09-01 00:35:01   2023-09-01 00:39:04           162
# 3               2  2023-09-01 00:45:45   2023-09-01 00:47:37           141
# 4               2  2023-09-01 00:01:23   2023-09-01 00:38:05           138
# ...           ...                  ...                   ...           ...
# 2846717         2  2023-09-30 23:31:12   2023-09-30 23:48:29           125
# 2846718         1  2023-09-30 23:42:18   2023-09-30 23:47:45           236
# 2846719         1  2023-09-30 23:03:35   2023-09-30 23:14:50           211
# 2846720         2  2023-09-30 23:57:05   2023-10-01 00:17:36           209
# 2846721         1  2023-09-30 23:25:47   2023-09-30 23:55:28            80
#
#          DOLocationID Partida_Borough           Partida_Zone Destino_Borough  \
# 0                 230       Manhattan          Midtown North       Manhattan
# 1                 233       Manhattan  Upper East Side North       Manhattan
# 2                 236       Manhattan           Midtown East       Manhattan
# 3                 229       Manhattan        Lenox Hill West       Manhattan
# 4                 230          Queens      LaGuardia Airport       Manhattan
# ...               ...             ...                    ...             ...
# 2846717           107       Manhattan              Hudson Sq       Manhattan
# 2846718            75       Manhattan  Upper East Side North       Manhattan
# 2846719            90       Manhattan                   SoHo       Manhattan
# 2846720            97       Manhattan                Seaport        Brooklyn
# 2846721           197        Brooklyn      East Williamsburg          Queens
#
#                           Destino_Zone
# 0            Times Sq/Theatre District
# 1                  UN/Turtle Bay South
# 2                Upper East Side North
# 3        Sutton Place/Turtle Bay North
# 4            Times Sq/Theatre District
# ...                                ...
# 2846717                       Gramercy
# 2846718              East Harlem South
# 2846719                       Flatiron
# 2846720                    Fort Greene
# 2846721                  Richmond Hill
#
# [2846722 rows x 9 columns]

# %% [markdown]
# Creo la columna de viajes intra o inter borough

# %%
# Agregar una nueva columna 'Borough_Category' basada en la comparación de las columnas 'Partida_Borough' y 'Destino_Borough'
df_merged['Borough_Category'] = df_merged.apply(lambda row: 'Intra Borough' if row['Partida_Borough'] == row['Destino_Borough'] else 'Inter Borough', axis=1)

# %%
df_merged
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  \
# 0               1  2023-09-01 00:15:37   2023-09-01 00:20:21           163
# 1               2  2023-09-01 00:18:40   2023-09-01 00:30:28           236
# 2               2  2023-09-01 00:35:01   2023-09-01 00:39:04           162
# 3               2  2023-09-01 00:45:45   2023-09-01 00:47:37           141
# 4               2  2023-09-01 00:01:23   2023-09-01 00:38:05           138
# ...           ...                  ...                   ...           ...
# 2846717         2  2023-09-30 23:31:12   2023-09-30 23:48:29           125
# 2846718         1  2023-09-30 23:42:18   2023-09-30 23:47:45           236
# 2846719         1  2023-09-30 23:03:35   2023-09-30 23:14:50           211
# 2846720         2  2023-09-30 23:57:05   2023-10-01 00:17:36           209
# 2846721         1  2023-09-30 23:25:47   2023-09-30 23:55:28            80
#
#          DOLocationID Partida_Borough           Partida_Zone Destino_Borough  \
# 0                 230       Manhattan          Midtown North       Manhattan
# 1                 233       Manhattan  Upper East Side North       Manhattan
# 2                 236       Manhattan           Midtown East       Manhattan
# 3                 229       Manhattan        Lenox Hill West       Manhattan
# 4                 230          Queens      LaGuardia Airport       Manhattan
# ...               ...             ...                    ...             ...
# 2846717           107       Manhattan              Hudson Sq       Manhattan
# 2846718            75       Manhattan  Upper East Side North       Manhattan
# 2846719            90       Manhattan                   SoHo       Manhattan
# 2846720            97       Manhattan                Seaport        Brooklyn
# 2846721           197        Brooklyn      East Williamsburg          Queens
#
#                           Destino_Zone Borough_Category
# 0            Times Sq/Theatre District    Intra Borough
# 1                  UN/Turtle Bay South    Intra Borough
# 2                Upper East Side North    Intra Borough
# 3        Sutton Place/Turtle Bay North    Intra Borough
# 4            Times Sq/Theatre District    Inter Borough
# ...                                ...              ...
# 2846717                       Gramercy    Intra Borough
# 2846718              East Harlem South    Intra Borough
# 2846719                       Flatiron    Intra Borough
# 2846720                    Fort Greene    Inter Borough
# 2846721                  Richmond Hill    Inter Borough
#
# [2846722 rows x 10 columns]

# %% [markdown]
# ## Viajes Inter e Intra Boroughs

# %%
# Contar la cantidad de viajes Intra e Inter Boroughs
intra_borough_count = df_merged[df_merged['Borough_Category'] == 'Intra Borough'].shape[0]
inter_borough_count = df_merged[df_merged['Borough_Category'] == 'Inter Borough'].shape[0]

print(f'Cantidad de viajes Intra Boroughs: {intra_borough_count}')
print(f'Cantidad de viajes Inter Boroughs: {inter_borough_count}')
# Out:
# Cantidad de viajes Intra Boroughs: 2426371
# Cantidad de viajes Inter Boroughs: 420351

# %% [markdown]
# #### Distribución de Viajes dentro del mismo Borough y entre distintos Borough

# %%
# que representan la cantidad de viajes entre distintas zonas y en la misma zona, respectivamente.

# Crear datos para el gráfico de torta
labels = ['Entre Distintos Boroughs (Inter)', 'En el Mismo Borough(Intra)']
sizes = [inter_borough_count, intra_borough_count]
colors = ['skyblue', 'lightgreen']

# Crear el gráfico de torta
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribución de Viajes Intra e Inter Borough')
plt.show()

# %% [markdown]
# La cantidad de viajes Intra Boroughs fue de 2426371 mientras que la Cantidad de viajes Inter Boroughs: 420351

# %% [markdown]
# ## Borough con mayor/menor cantidad de INTRA viajes

# %%
# Filtrar solo los viajes Intra Borough
intra_borough_trips = df_merged[df_merged['Borough_Category'] == 'Intra Borough']

# Contar la cantidad de viajes Intra Borough por cada borough
intra_borough_trip_counts = intra_borough_trips['Partida_Borough'].value_counts()

# Obtener el borough con mayor cantidad de viajes Intra Borough
borough_intra_max = intra_borough_trip_counts.idxmax()
cantidad_viajes_intra_max = intra_borough_trip_counts.max()

# Obtener el borough con menor cantidad de viajes Intra Borough
borough_intra_min = intra_borough_trip_counts.idxmin()
cantidad_viajes_intra_min = intra_borough_trip_counts.min()

print(f'Borough con mayor cantidad de viajes Intra Borough: {borough_intra_max} ({cantidad_viajes_intra_max} viajes)')
print(f'Borough con menor cantidad de viajes Intra Borough: {borough_intra_min} ({cantidad_viajes_intra_min} viajes)')
# Out:
# Borough con mayor cantidad de viajes Intra Borough: Manhattan (2315292 viajes)
# Borough con menor cantidad de viajes Intra Borough: Staten Island (57 viajes)

# %% [markdown]
# ####  Cantidad de viajes Intra Borough por borough en un gráfico

# %% [markdown]
# Cantidad de Viajes Intra Boroughs por Borough (viaje dentro de un mismo Borough):

# %%
# Filtrar solo los viajes Intra Borough
intra_borough_trips = df_merged[df_merged['Borough_Category'] == 'Intra Borough']

# Contar la cantidad de viajes Intra Borough por cada borough
intra_borough_trip_counts = intra_borough_trips['Partida_Borough'].value_counts()

# Crear un gráfico de barras
plt.figure(figsize=(10, 6))
intra_borough_trip_counts.plot(kind='bar', color='skyblue')
plt.title('Cantidad de Viajes Intra Borough por Borough')
plt.xlabel('Borough')
plt.ylabel('Cantidad de Viajes')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Borough con mayor cantidad de viajes Intra Borough: Manhattan (2315292 viajes).  El Borough con menor cantidad de viajes Intra Borough: Staten Island (57 viajes)

# %% [markdown]
# #### "Análisis de Viajes INTER Boroughs por Combinación de Partida y Destino"

# %%
# Filtrar solo los viajes Inter Borough
inter_borough_trips = df_merged[df_merged['Borough_Category'] == 'Inter Borough']

# Contar la cantidad de viajes para cada combinación de Partida_Borough y Destino_Borough
inter_borough_counts = inter_borough_trips.groupby(['Partida_Borough', 'Destino_Borough']).size().reset_index(name='Cantidad_Viajes')

# Ordenar el DataFrame inter_borough_counts de mayor a menor cantidad de viajes
inter_borough_counts_sorted = inter_borough_counts.sort_values(by='Cantidad_Viajes', ascending=False)

# Mostrar el resultado ordenado
print('Cantidad de viajes para cada combinación de Partida_Borough y Destino_Borough (de mayor a menor):')
print(inter_borough_counts_sorted)
# Out:
# Cantidad de viajes para cada combinación de Partida_Borough y Destino_Borough (de mayor a menor):
#    Partida_Borough Destino_Borough  Cantidad_Viajes
# 23          Queens       Manhattan           165556
# 17       Manhattan          Queens            88527
# 15       Manhattan        Brooklyn            58841
# 21          Queens        Brooklyn            43421
# 19       Manhattan         Unknown            10942
# 25          Queens         Unknown             9485
# 7         Brooklyn       Manhattan             9262
# 16       Manhattan             EWR             8188
# 14       Manhattan           Bronx             8140
# 20          Queens           Bronx             6413
# 8         Brooklyn          Queens             3042
# 34         Unknown       Manhattan             2803
# 2            Bronx       Manhattan             1937
# 35         Unknown          Queens              506
# 22          Queens             EWR              447
# 3            Bronx          Queens              442
# 24          Queens   Staten Island              419
# 0            Bronx        Brooklyn              407
# 5         Brooklyn           Bronx              350
# 32         Unknown        Brooklyn              339
# 18       Manhattan   Staten Island              275
# 31         Unknown           Bronx              150
# 10        Brooklyn         Unknown              140
# 6         Brooklyn             EWR               86
# 4            Bronx         Unknown               67
# 33         Unknown             EWR               51
# 13             EWR         Unknown               26
# 9         Brooklyn   Staten Island               26
# 29   Staten Island          Queens               14
# 26   Staten Island        Brooklyn               12
# 11             EWR       Manhattan               10
# 30   Staten Island         Unknown                8
# 36         Unknown   Staten Island                8
# 28   Staten Island       Manhattan                4
# 1            Bronx             EWR                3
# 12             EWR          Queens                2
# 27   Staten Island             EWR                2

# %%
# Filtrar solo los viajes INTER Boroughs
inter_borough_trips = df_merged[df_merged['Borough_Category'] == 'Inter Borough']

# Contar la cantidad de viajes para cada combinación de Partida_Borough y Destino_Borough
inter_borough_counts = inter_borough_trips.groupby(['Partida_Borough', 'Destino_Borough']).size().reset_index(name='Cantidad_Viajes')

# Crear un gráfico de barras con colores distintos para cada combinación
plt.figure(figsize=(12, 8))
sns.barplot(x='Partida_Borough', y='Cantidad_Viajes', hue='Destino_Borough', data=inter_borough_counts)
plt.title('Análisis de Viajes INTER Boroughs por Combinación de Partida y Destino')
plt.xlabel('Borough de Partida')
plt.ylabel('Cantidad de Viajes')
plt.legend(title='Borough de Destino', title_fontsize='12')
plt.show()

# %% [markdown]
# Se puede ver que los viajes más frencuentes son de Queens a Manhattan (165556 viajes) y viceversa de Manhattan a Queens (88527- viajes ).

# %% [markdown]
# ## Viajes por zonas

# %% [markdown]
# #### Cantidad de viajes entre distintas (INTER) zonas

# %%
# Contar la cantidad de viajes entre distintas zonas
viajes_entre_zonas_count = df_merged[df_merged['Partida_Zone'] != df_merged['Destino_Zone']].shape[0]

print(f'Cantidad de viajes entre distintas zonas: {viajes_entre_zonas_count}')
# Out:
# Cantidad de viajes entre distintas zonas: 2683471

# %%
# Contar la cantidad de viajes entre distintas zonas
viajes_en_misma_zona_count = df_merged[df_merged['Partida_Zone'] == df_merged['Destino_Zone']].shape[0]

print(f'Cantidad de viajes en la misma zona: {viajes_en_misma_zona_count}')
# Out:
# Cantidad de viajes en la misma zona: 163251

# %% [markdown]
# #### Cantidad de Viajes Intra Zona vs Inter Zona

# %%
# Contar la cantidad de viajes entre distintas zonas y en la misma zona
viajes_entre_zonas_count = df_merged[df_merged['Partida_Zone'] != df_merged['Destino_Zone']].shape[0]
viajes_en_misma_zona_count = df_merged[df_merged['Partida_Zone'] == df_merged['Destino_Zone']].shape[0]

# Crear datos para el gráfico de torta
labels = ['Entre Distintas Zonas', 'En la Misma Zona']
sizes = [viajes_entre_zonas_count, viajes_en_misma_zona_count]
colors = ['skyblue', 'lightgreen']

# Crear el gráfico de torta
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribución de Viajes entre Distintas y En la Misma Zona')
plt.show()

# %% [markdown]
# Son más frecuentes los viajes entre distintas zonas.

# %% [markdown]
# #### Cantidad de viajes entre distintas zonas por combinación de Partida_Zone y Destino_Zone (indistinto al orden):

# %%
# Supongamos que df_merged es tu DataFrame original

# Filtrar solo los viajes entre distintas zonas
viajes_entre_zonas_counts = df_merged[df_merged['Partida_Zone'] != df_merged['Destino_Zone']]

# Crear una nueva columna con combinaciones ordenadas alfabéticamente
viajes_entre_zonas_counts['Combinacion_Zonas'] = viajes_entre_zonas_counts.apply(lambda row: '-'.join(sorted([str(row['Partida_Zone']), str(row['Destino_Zone'])])), axis=1)

# Contar la cantidad de viajes para cada combinación de zonas
viajes_entre_zonas_counts_aggregated = viajes_entre_zonas_counts.groupby('Combinacion_Zonas').size().reset_index(name='Cantidad_Viajes')

# Ordenar el DataFrame por la cantidad de viajes de mayor a menor
viajes_entre_zonas_counts_aggregated_sorted = viajes_entre_zonas_counts_aggregated.sort_values(by='Cantidad_Viajes', ascending=False)

# Mostrar el resultado
print('Cantidad de viajes entre distintas zonas por combinación de Partida_Zone y Destino_Zone (indistinto al orden):')
viajes_entre_zonas_counts_aggregated_sorted.head()
# Out:
# C:\Users\Heidi\AppData\Local\Temp\ipykernel_11080\2828902156.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   viajes_entre_zonas_counts['Combinacion_Zonas'] = viajes_entre_zonas_counts.apply(lambda row: '-'.join(sorted([str(row['Partida_Zone']), str(row['Destino_Zone'])])), axis=1)
# Cantidad de viajes entre distintas zonas por combinación de Partida_Zone y Destino_Zone (indistinto al orden):
#                                  Combinacion_Zonas  Cantidad_Viajes
# 15840  Upper East Side North-Upper East Side South            37254
# 13298         Midtown Center-Upper East Side South            17183
# 12222    Lincoln Square East-Upper West Side South            14132
# 13297         Midtown Center-Upper East Side North            13162
# 13394           Midtown East-Upper East Side South            12993
# ...                                            ...              ...
# 11322                           Jamaica-Mount Hope                1
# 3776            Central Harlem North-Starrett City                1
# 11313      Jamaica-Marine Park/Floyd Bennett Field                1
# 11311                      Jamaica-Manhattan Beach                1
# 0             Allerton/Pelham Gardens-Bedford Park                1
#
# [16097 rows x 2 columns]
#                                  Combinacion_Zonas  Cantidad_Viajes
# 15840  Upper East Side North-Upper East Side South            37254
# 13298         Midtown Center-Upper East Side South            17183
# 12222    Lincoln Square East-Upper West Side South            14132
# 13297         Midtown Center-Upper East Side North            13162
# 13394           Midtown East-Upper East Side South            12993

# %%
viajes_entre_zonas_counts_aggregated_sorted.to_csv('viajes entre distintas zonas.csv')
Veinte_Inter_Zonas_con_mas_viajes = viajes_entre_zonas_counts_aggregated_sorted.head(20)
Veinte_Inter_Zonas_con_mas_viajes
# Out:
#                                        Combinacion_Zonas  Cantidad_Viajes
# 15840        Upper East Side North-Upper East Side South            37254
# 13298               Midtown Center-Upper East Side South            17183
# 12222          Lincoln Square East-Upper West Side South            14132
# 13297               Midtown Center-Upper East Side North            13162
# 13394                 Midtown East-Upper East Side South            12993
# 15893        Upper West Side North-Upper West Side South            12757
# 12111              Lenox Hill West-Upper East Side North            12086
# 12112              Lenox Hill West-Upper East Side South            11174
# 15842        Upper East Side North-Upper West Side South            10736
# 12220          Lincoln Square East-Upper East Side South            10669
# 11097              JFK Airport-Times Sq/Theatre District            10515
# 11840        LaGuardia Airport-Times Sq/Theatre District            10265
# 13393                 Midtown East-Upper East Side North             9981
# 12221          Lincoln Square East-Upper West Side North             9934
# 14545  Penn Station/Madison Sq West-Times Sq/Theatre ...             9838
# 15864               Upper East Side North-Yorkville West             9598
# 15863               Upper East Side North-Yorkville East             9582
# 15841        Upper East Side North-Upper West Side North             9501
# 4425                           Clinton East-East Chelsea             9443
# 12219          Lincoln Square East-Upper East Side North             9397

# %% [markdown]
# #### Grafico Veinte Combinaciones de Zonas con más Viajes]

# %%
# Ordenar el DataFrame de mayor a menor por la columna 'Cantidad_Viajes'
Veinte_Inter_Zonas_con_mas_viajes_sorted = Veinte_Inter_Zonas_con_mas_viajes.sort_values(by='Cantidad_Viajes', ascending=True)

# Crear un gráfico de barras horizontales
plt.figure(figsize=(12, 8))
plt.barh(Veinte_Inter_Zonas_con_mas_viajes_sorted['Combinacion_Zonas'], Veinte_Inter_Zonas_con_mas_viajes_sorted['Cantidad_Viajes'], color='skyblue')
plt.xlabel('Cantidad de Viajes')
plt.ylabel('Combinación de Zonas')
plt.title('Veinte Combinaciones de Zonas con más Viajes (Ordenadas de Mayor a Menor)')
plt.show()

# %% [markdown]
# La ruta más frecuente entre zonas ees: Upper East Side North-Upper East Side South con	37254 viajes. Le sigue Midtown Center-Upper East Side South con	17183 viajes.

# %%
Veinte_Inter_Zonas_con_mas_viajes.to_csv('20 Inter Zonas con mas viajes indiferente del orden Partida Destino.csv')

# %% [markdown]
# ## Relacionar días y horarios de la semana con combinaciones de zonas de viaje

# %%
# Convertir las columnas de fecha y hora al formato datetime
df_merged['tpep_pickup_datetime'] = pd.to_datetime(df_merged['tpep_pickup_datetime'])
df_merged['tpep_dropoff_datetime'] = pd.to_datetime(df_merged['tpep_dropoff_datetime'])

# Agregar columnas para el día de la semana y la hora del día
df_merged['day_of_week'] = df_merged['tpep_pickup_datetime'].dt.day_name()
df_merged['hour_of_day'] = df_merged['tpep_pickup_datetime'].dt.hour

# %%
df_merged
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  PULocationID  \
# 0               1  2023-09-01 00:15:37   2023-09-01 00:20:21           163
# 1               2  2023-09-01 00:18:40   2023-09-01 00:30:28           236
# 2               2  2023-09-01 00:35:01   2023-09-01 00:39:04           162
# 3               2  2023-09-01 00:45:45   2023-09-01 00:47:37           141
# 4               2  2023-09-01 00:01:23   2023-09-01 00:38:05           138
# ...           ...                  ...                   ...           ...
# 2846717         2  2023-09-30 23:31:12   2023-09-30 23:48:29           125
# 2846718         1  2023-09-30 23:42:18   2023-09-30 23:47:45           236
# 2846719         1  2023-09-30 23:03:35   2023-09-30 23:14:50           211
# 2846720         2  2023-09-30 23:57:05   2023-10-01 00:17:36           209
# 2846721         1  2023-09-30 23:25:47   2023-09-30 23:55:28            80
#
#          DOLocationID Partida_Borough           Partida_Zone Destino_Borough  \
# 0                 230       Manhattan          Midtown North       Manhattan
# 1                 233       Manhattan  Upper East Side North       Manhattan
# 2                 236       Manhattan           Midtown East       Manhattan
# 3                 229       Manhattan        Lenox Hill West       Manhattan
# 4                 230          Queens      LaGuardia Airport       Manhattan
# ...               ...             ...                    ...             ...
# 2846717           107       Manhattan              Hudson Sq       Manhattan
# 2846718            75       Manhattan  Upper East Side North       Manhattan
# 2846719            90       Manhattan                   SoHo       Manhattan
# 2846720            97       Manhattan                Seaport        Brooklyn
# 2846721           197        Brooklyn      East Williamsburg          Queens
#
#                           Destino_Zone Borough_Category day_of_week  \
# 0            Times Sq/Theatre District    Intra Borough      Friday
# 1                  UN/Turtle Bay South    Intra Borough      Friday
# 2                Upper East Side North    Intra Borough      Friday
# 3        Sutton Place/Turtle Bay North    Intra Borough      Friday
# 4            Times Sq/Theatre District    Inter Borough      Friday
# ...                                ...              ...         ...
# 2846717                       Gramercy    Intra Borough    Saturday
# 2846718              East Harlem South    Intra Borough    Saturday
# 2846719                       Flatiron    Intra Borough    Saturday
# 2846720                    Fort Greene    Inter Borough    Saturday
# 2846721                  Richmond Hill    Inter Borough    Saturday
#
#          hour_of_day
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2846717           23
# 2846718           23
# 2846719           23
# 2846720           23
# 2846721           23
#
# [2846722 rows x 12 columns]

# %%
# Agrupar por día de la semana, hora del día y combinaciones de zonas de viaje
grouped_data = df_merged.groupby(['day_of_week', 'hour_of_day', 'Partida_Zone', 'Destino_Zone']).size().reset_index(name='count')
grouped_data = grouped_data.sort_values(by='count', ascending=False)

# Mostrar el resultado
grouped_data
# Out:
#        day_of_week  hour_of_day            Partida_Zone  \
# 493363   Wednesday           18   Upper East Side South
# 489449   Wednesday           17   Upper East Side South
# 405878     Tuesday           14   Upper East Side South
# 413155     Tuesday           16   Upper East Side South
# 481940   Wednesday           15   Upper East Side South
# ...            ...          ...                     ...
# 355397    Thursday           20         Lenox Hill West
# 167944    Saturday            7           Midtown South
# 167943    Saturday            7           Midtown South
# 167942    Saturday            7           Midtown South
# 136224      Monday           20  Charleston/Tottenville
#
#                   Destino_Zone  count
# 493363   Upper East Side North    341
# 489449   Upper East Side North    328
# 405878   Upper East Side North    324
# 413155   Upper East Side North    323
# 481940   Upper East Side North    322
# ...                        ...    ...
# 355397       LaGuardia Airport      1
# 167944     Little Italy/NoLiTa      1
# 167943         Lenox Hill West      1
# 167942         Lenox Hill East      1
# 136224  Charleston/Tottenville      1
#
# [514375 rows x 5 columns]

# %% [markdown]
# 2. Promedio de viajes por hora del día:

# %%
promedio_viajes_por_hora = df_merged.groupby('hour_of_day').size().reset_index(name='num_viajes')
promedio_viajes_por_hora['promedio_viajes'] = promedio_viajes_por_hora['num_viajes'] / len(grouped_data['day_of_week'].unique())

 #Ordenar el DataFrame por la columna 'promedio_viajes' de mayor a menor
promedio_viajes_por_hora = promedio_viajes_por_hora.sort_values(by='promedio_viajes', ascending=False)
promedio_viajes_por_hora
# Out:
#     hour_of_day  num_viajes  promedio_viajes
# 18           18      199970     28567.142857
# 17           17      193302     27614.571429
# 19           19      180420     25774.285714
# 16           16      171613     24516.142857
# 15           15      169447     24206.714286
# 20           20      165849     23692.714286
# 14           14      163711     23387.285714
# 21           21      159105     22729.285714
# 12           12      154212     22030.285714
# 13           13      153979     21997.000000
# 22           22      145590     20798.571429
# 11           11      144444     20634.857143
# 10           10      134991     19284.428571
# 9             9      125097     17871.000000
# 23           23      117289     16755.571429
# 8             8      114412     16344.571429
# 7             7       86619     12374.142857
# 0             0       80223     11460.428571
# 1             1       52080      7440.000000
# 6             6       43311      6187.285714
# 2             2       34496      4928.000000
# 3             3       23100      3300.000000
# 5             5       17385      2483.571429
# 4             4       16077      2296.714286

# %%
# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
plt.bar(promedio_viajes_por_hora['hour_of_day'], promedio_viajes_por_hora['promedio_viajes'], color='skyblue')
plt.title('Promedio de Viajes por Hora del Día')
plt.xlabel('Hora del Día')
plt.ylabel('Promedio de Viajes')
plt.xticks(promedio_viajes_por_hora['hour_of_day'])
plt.show()

# %%
variacion_por_dia = df_merged.groupby(['day_of_week', 'hour_of_day']).size().reset_index(name='num_viajes')
print(variacion_por_dia)
# Out:
#     day_of_week  hour_of_day  num_viajes
# 0        Friday            0       13352
# 1        Friday            1        8014
# 2        Friday            2        4583
# 3        Friday            3        2662
# 4        Friday            4        2186
# ..          ...          ...         ...
# 163   Wednesday           19       31654
# 164   Wednesday           20       30841
# 165   Wednesday           21       30100
# 166   Wednesday           22       25919
# 167   Wednesday           23       17440
#
# [168 rows x 3 columns]

# %% [markdown]
# ### Variación por día y hora de la semana:

# %%
# Ordenar los días de la semana
ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
variacion_por_dia['day_of_week'] = pd.Categorical(variacion_por_dia['day_of_week'], categories=ordered_days, ordered=True)

# Configurar el tamaño del gráfico
plt.figure(figsize=(15, 8))

# Crear un gráfico de barras
heatmap_data = variacion_por_dia.pivot_table(index='hour_of_day', columns='day_of_week', values='num_viajes', aggfunc='sum')
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)

# Configurar etiquetas y título
plt.title('Variación del número de viajes por día de la semana y hora del día')
plt.xlabel('Día de la semana')
plt.ylabel('Hora del día')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Crear una función en Python que tome como parámetros el día actual, el rango horario, la zona de partida y la zona de destino, y devuelva el día y la hora recomendados para viajar donde hay menos cantidad de viajes.

# %% [markdown]
#      # Obtener la fecha y hora actuales

# %%
def obtener_dia_actual():
    # Obtener la fecha y hora actuales
    ahora = datetime.now()

    # Obtener el nombre del día de la semana
    dia_actual = ahora.strftime('%A')

    return dia_actual

# %%
def sugerir_mejor_momento(rango_horario, zona_partida, zona_destino, grouped_data):
    # Filtrar por rango horario, zona de partida y destino
    filtro_rango_horario = (grouped_data['hour_of_day'].between(rango_horario[0], rango_horario[1]))
    filtro_partida = (grouped_data['Partida_Zone'] == zona_partida)
    filtro_destino = (grouped_data['Destino_Zone'] == zona_destino)

    viajes_filtrados = grouped_data[filtro_rango_horario & filtro_partida & filtro_destino]

    # Agrupar por día de la semana y rango horario, contar la cantidad de viajes y ordenar de menor a mayor
    viajes_por_dia_y_horario = viajes_filtrados.groupby(['day_of_week', 'hour_of_day']).size().sort_values()

    # Obtener la primera y segunda alternativa
    primera_alternativa = viajes_por_dia_y_horario.idxmin()
    viajes_por_dia_y_horario = viajes_por_dia_y_horario.drop(primera_alternativa)
    segunda_alternativa = viajes_por_dia_y_horario.idxmin()

    return primera_alternativa, segunda_alternativa

# Ejemplo de uso
rango_horario = (6, 12)
zona_partida = 'Upper East Side South'
zona_destino = 'Upper East Side North'
resultado = sugerir_mejor_momento(rango_horario, zona_partida, zona_destino, grouped_data)
print("Primera alternativa:", resultado[0])
print("Segunda alternativa:", resultado[1])
# Out:
# Primera alternativa: ('Friday', 6)
# Segunda alternativa: ('Sunday', 11)
